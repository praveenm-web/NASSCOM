# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenm-web/NASSCOM/blob/main/Day6_MSE_and_R%C2%B2_Score_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_true = [3, 5, 2.5, 7]
y_pred = [2.8, 4.9, 2.7, 7.2]

mse = mean_squared_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)

print("MSE:", mse)
print("R² Score:", r2)
# Out:
# MSE: 0.032500000000000036
# R² Score: 0.9897536945812808
